# %%
import os
print( os.getcwd())
# !dir
# Out:
# C:\Users\Lavanaya_Chandra\Documents\eta-ml-project
#  Volume in drive C has no label.
#  Volume Serial Number is 4887-D11D
#
#  Directory of C:\Users\Lavanaya_Chandra\Documents\eta-ml-project
#
# 08/19/2026  12:40 AM    <DIR>          .
# 08/19/2026  12:40 AM    <DIR>          ..
# 08/19/2026  12:37 AM               681 .gitignore
# 08/19/2026  12:40 AM    <DIR>          .ipynb_checkpoints
# 08/19/2026  12:37 AM    <DIR>          api
# 08/19/2026  12:37 AM    <DIR>          data
# 08/19/2026  12:37 AM             1,924 Dockerfile
# 08/19/2026  12:37 AM    <DIR>          docs
# 08/19/2026  12:37 AM    <DIR>          models
# 08/17/2026  06:11 PM    <DIR>          monitoring
# 08/17/2026  06:11 PM    <DIR>          notebooks
# 08/19/2026  12:37 AM    <DIR>          reports
# 08/19/2026  12:37 AM               225 requirements.txt
# 08/19/2026  12:37 AM    <DIR>          src
# 08/19/2026  12:37 AM    <DIR>          tests
# 08/19/2026  12:40 AM               337 Untitled.ipynb
# ...

# %%
# !pip install -r requirements.txt
# !python -m unittest discover -s tests -v
# Out:
# ...
# test_api (unittest.loader._FailedTest.test_api) ... ERROR
# test_evaluate_perfect_predictions_gives_zero_error (test_train.TestTrain.test_evaluate_perfect_predictions_gives_zero_error) ... ok
# test_evaluate_returns_expected_keys (test_train.TestTrain.test_evaluate_returns_expected_keys) ... ok
# test_same_seed_gives_identical_model_fit (test_train.TestTrain.test_same_seed_gives_identical_model_fit) ... ok
# test_duplicate_rows_deduplicated (test_validate_data.TestValidateData.test_duplicate_rows_deduplicated) ... ok
# test_invalid_timestamp_is_dropped (test_validate_data.TestValidateData.test_invalid_timestamp_is_dropped) ... ok
# test_missing_gps_is_dropped (test_validate_data.TestValidateData.test_missing_gps_is_dropped) ... ok
# test_missing_schema_column_raises (test_validate_data.TestValidateData.test_missing_schema_column_raises) ... ok
# test_missing_weather_is_imputed_not_dropped (test_validate_data.TestValidateData.test_missing_weather_is_imputed_not_dropped) ... ok
# ...

# %%
# !python src/models/train.py
# Out:
# [linear_regression] MAE=4.042min RMSE=5.298min R2=0.9018
# [gradient_boosting_default] MAE=3.318min RMSE=4.187min R2=0.9387
# [gradient_boosting_tuned_shallow] MAE=3.321min RMSE=4.189min R2=0.9386
# [gradient_boosting_tuned_deep] MAE=3.324min RMSE=4.193min R2=0.9385
#
# Best model: gradient_boosting_default (RMSE=4.187 min)
# Promoted to C:\Users\Lavanaya_Chandra\Documents\eta-ml-project\models\best_model.joblib
# Comparison report written to C:\Users\Lavanaya_Chandra\Documents\eta-ml-project\reports\model_comparison.json
# Model version manifest updated: sha256=47ff64507ad4...
# 2026/08/19 01:07:40 INFO mlflow.tracking.fluent: Experiment with name 'eta-prediction' does not exist. Creating a new experiment.

# %%
# !python -m unittest discover -s tests -v
# Out:
# test_health_endpoint (test_api.TestAPI.test_health_endpoint) ... ok
# test_invalid_timestamp_returns_422 (test_api.TestAPI.test_invalid_timestamp_returns_422) ... ok
# test_invalid_weather_returns_422 (test_api.TestAPI.test_invalid_weather_returns_422) ... ok
# test_malformed_json_returns_400 (test_api.TestAPI.test_malformed_json_returns_400) ... ok
# test_missing_required_field_returns_422 (test_api.TestAPI.test_missing_required_field_returns_422) ... ok
# test_missing_weather_defaults_to_unknown (test_api.TestAPI.test_missing_weather_defaults_to_unknown) ... ok
# test_out_of_range_latitude_returns_422 (test_api.TestAPI.test_out_of_range_latitude_returns_422) ... ok
# test_response_is_deterministic_for_same_input (test_api.TestAPI.test_response_is_deterministic_for_same_input) ... ok
# test_valid_prediction_returns_200 (test_api.TestAPI.test_valid_prediction_returns_200) ... ok
# ...

# %%
cd C:\Users\Lavanaya_Chandra\Documents\eta-ml-project
mlflow ui
